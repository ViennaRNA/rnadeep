# %% [markdown]
# <a href="https://colab.research.google.com/github/ViennaRNA/RNAdeep/blob/dev_data/SpotrnaPaddedDataInverseRNAbp_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment setup

# %%
# We are assuming the Python environment is 3.7.
# otherwise you have to adjust the miniconda version below:
import sys
sys.version
# Out:
# '3.7.13 (default, Mar 16 2022, 17:37:17) \n[GCC 7.5.0]'

# %%
# install miniconda
#!wget -qO ac.sh https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !wget -qO ac.sh https://repo.anaconda.com/miniconda/Miniconda3-py37_4.11.0-Linux-x86_64.sh # Python 3.7
# !bash ./ac.sh -b -f -p /usr/local/
# !rm ac.sh
# !conda update -y conda
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2021.10.26=h06a4308_2
#     - certifi==2021.10.8=py37h06a4308_2
#     - cffi==1.15.0=py37hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.7.3=py37h27cfd23_1
#     - conda==4.11.0=py37h06a4308_0
#     - cryptography==36.0.0=py37h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1m=h7f8727e_0
#     - pip==21.2.2=py37h06a4308_0
#     - pycosat==0.6.3=py37h27cfd23_0
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==21.0.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py37_1
#     - python==3.7.11=h12debd9_0
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py37h27cfd23_0
#     - setuptools==58.0.4=py37h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_0
#     - sqlite==3.37.0=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.62.3=pyhd3eb1b0_1
#     - urllib3==1.26.7=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7f8727e_4
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py37h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2021.10.26-h06a4308_2
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py37h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py37hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.11.0-py37h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.3-py37h27cfd23_1
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py37h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1m-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.2-py37h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-21.0.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_1
#   python             pkgs/main/linux-64::python-3.7.11-h12debd9_0
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py37h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-58.0.4-py37h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_0
#   sqlite             pkgs/main/linux-64::sqlite-3.37.0-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb1b0_1
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7f8727e_4
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.3.29  |       h06a4308_1         122 KB
#     colorama-0.4.4             |     pyhd3eb1b0_0          21 KB
#     conda-4.12.0               |   py37h06a4308_0        14.5 MB
#     conda-package-handling-1.8.1|   py37h7f8727e_0         889 KB
#     openssl-1.1.1n             |       h7f8727e_0         2.5 MB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     setuptools-61.2.0          |   py37h06a4308_0        1007 KB
#     sqlite-3.38.2              |       hc218d9a_0         1.0 MB
#     tqdm-4.63.0                |     pyhd3eb1b0_0          84 KB
#     urllib3-1.26.8             |     pyhd3eb1b0_0         106 KB
#     zlib-1.2.12                |       h7f8727e_2         106 KB
#     ------------------------------------------------------------
#                                            Total:        20.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd3eb1b0_0
#
# The following packages will be REMOVED:
#
#   conda-content-trust-0.1.1-pyhd3eb1b0_0
#   six-1.16.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2021.10.26-h06a4308_2 --> 2022.3.29-h06a4308_1
#   conda                               4.11.0-py37h06a4308_0 --> 4.12.0-py37h06a4308_0
#   conda-package-han~                   1.7.3-py37h27cfd23_1 --> 1.8.1-py37h7f8727e_0
#   openssl                                 1.1.1m-h7f8727e_0 --> 1.1.1n-h7f8727e_0
#   pyopenssl                             21.0.0-pyhd3eb1b0_1 --> 22.0.0-pyhd3eb1b0_0
#   setuptools                          58.0.4-py37h06a4308_0 --> 61.2.0-py37h06a4308_0
#   sqlite                                  3.37.0-hc218d9a_0 --> 3.38.2-hc218d9a_0
#   tqdm                                  4.62.3-pyhd3eb1b0_1 --> 4.63.0-pyhd3eb1b0_0
#   urllib3                               1.26.7-pyhd3eb1b0_0 --> 1.26.8-pyhd3eb1b0_0
#   zlib                                    1.2.11-h7f8727e_4 --> 1.2.12-h7f8727e_2
#
#
#
# Downloading and Extracting Packages
# sqlite-3.38.2        | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  6.64it/s]
# ca-certificates-2022 | 122 KB    | : 100% 1.0/1 [00:00<00:00, 14.54it/s]
# openssl-1.1.1n       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  6.42it/s]
# setuptools-61.2.0    | 1007 KB   | : 100% 1.0/1 [00:00<00:00,  6.69it/s]
# conda-4.12.0         | 14.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# tqdm-4.63.0          | 84 KB     | : 100% 1.0/1 [00:00<00:00, 15.30it/s]
# colorama-0.4.4       | 21 KB     | : 100% 1.0/1 [00:00<00:00, 16.34it/s]
# conda-package-handli | 889 KB    | : 100% 1.0/1 [00:00<00:00, 11.61it/s]
# urllib3-1.26.8       | 106 KB    | : 100% 1.0/1 [00:00<00:00, 14.93it/s]
# pyopenssl-22.0.0     | 50 KB     | : 100% 1.0/1 [00:00<00:00, 15.95it/s]
# zlib-1.2.12          | 106 KB    | : 100% 1.0/1 [00:00<00:00, 15.95it/s]
# done
# done
# done

# %%
# install viennarna, etc.
# !conda config --add channels bioconda
# !conda config --add channels conda-forge
# !conda install -y  viennarna
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - viennarna
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py37h89c1867_2         145 KB  conda-forge
#     conda-4.12.0               |   py37h89c1867_0         1.0 MB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     viennarna-2.4.18           |   py37hfecc14a_0        14.3 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        15.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
#   viennarna          bioconda/linux-64::viennarna-2.4.18-py37hfecc14a_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.3.29-~ --> conda-forge::ca-certificates-2021.10.8-ha878542_0
#   certifi            pkgs/main::certifi-2021.10.8-py37h06a~ --> conda-forge::certifi-2021.10.8-py37h89c1867_2
#   conda              pkgs/main::conda-4.12.0-py37h06a4308_0 --> conda-forge::conda-4.12.0-py37h89c1867_0
#
#
#
# Downloading and Extracting Packages
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 10.61it/s]
# viennarna-2.4.18     | 14.3 MB   | : 100% 1.0/1 [00:03<00:00,  3.18s/it]
# certifi-2021.10.8    | 145 KB    | : 100% 1.0/1 [00:00<00:00, 13.73it/s]
# conda-4.12.0         | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  3.42it/s]
# ca-certificates-2021 | 139 KB    | : 100% 1.0/1 [00:00<00:00, 14.95it/s]
# done
# done
# done

# %%
# Clone the RNAdeep repository
try:
  # !git clone https://github.com/ViennaRNA/RNAdeep.git RNAdeep
except:
  pass  
# %cd RNAdeep
# !git checkout -b dev_data
# !git pull origin dev_data
# !python ./setup.py install
# %cd ..
# Out:
# Cloning into 'RNAdeep'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 115 (delta 29), reused 56 (delta 16), pack-reused 34
# Receiving objects: 100% (115/115), 297.12 KiB | 2.15 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/RNAdeep
# Switched to a new branch 'dev_data'
# From https://github.com/ViennaRNA/RNAdeep
#  * branch            dev_data   -> FETCH_HEAD
# Updating 7f117a5..20586aa
# Fast-forward
#  .gitignore                             |   4 +
#  examples/blstm_linear.py               |  51 +++++++
#  examples/generate_data.py              |  86 +++++++++++
#  examples/learning_curves.py            |  60 ++++++++
#  examples/lstm_windows.py               |  52 +++++++
#  examples/spotrna_fixedlength.py        |  63 ++++++++
#  examples/spotrna_padded.py             |  63 ++++++++
#  models/data_generators.py              | 129 ----------------
#  models/data_generators_rna.py          |  59 --------
#  models/encoding_utils.py               |  56 -------
#  models/encoding_utils_rna.py           |  79 ----------
#  notebooks/SpotrnaPaddedData.ipynb      | 266 +++++++++++++++++++++++++++++++++
#  notebooks/learningcurves.ipynb         | 113 --------------
#  notebooks/spotrna_training.ipynb       | 191 -----------------------
#  notebooks/windows_lstms_learning.ipynb | 176 ----------------------
#  requirements.txt                       |   2 +
#  rnadeep/__init__.py                    |   2 +
#  rnadeep/data_generators.py             |  82 ++++++++++
#  rnadeep/encoding_utils.py              | 116 ++++++++++++++
#  {models => rnadeep}/lstm_models.py     |   3 -
#  {models => rnadeep}/metrics.py         |   5 +-
#  rnadeep/sampling.py                    |  75 ++++++++++
#  {models => rnadeep}/sliding_window.py  |   0
#  {models => rnadeep}/spotrna.py         |  10 +-
#  setup.py                               |  25 ++++
#  tests/__init__.py                      |   0
#  tests/test_encoding_utils.py           |  35 +++++
#  27 files changed, 986 insertions(+), 817 deletions(-)
#  create mode 100644 .gitignore
#  create mode 100644 examples/blstm_linear.py
#  create mode 100644 examples/generate_data.py
#  create mode 100644 examples/learning_curves.py
#  create mode 100644 examples/lstm_windows.py
#  create mode 100644 examples/spotrna_fixedlength.py
#  create mode 100644 examples/spotrna_padded.py
#  delete mode 100644 models/data_generators.py
#  delete mode 100644 models/data_generators_rna.py
#  delete mode 100644 models/encoding_utils.py
#  delete mode 100644 models/encoding_utils_rna.py
#  create mode 100644 notebooks/SpotrnaPaddedData.ipynb
#  delete mode 100644 notebooks/learningcurves.ipynb
#  delete mode 100644 notebooks/spotrna_training.ipynb
#  delete mode 100644 notebooks/windows_lstms_learning.ipynb
#  create mode 100644 requirements.txt
#  create mode 100644 rnadeep/__init__.py
#  create mode 100644 rnadeep/data_generators.py
#  create mode 100644 rnadeep/encoding_utils.py
#  rename {models => rnadeep}/lstm_models.py (93%)
#  rename {models => rnadeep}/metrics.py (95%)
#  create mode 100644 rnadeep/sampling.py
#  rename {models => rnadeep}/sliding_window.py (100%)
#  rename {models => rnadeep}/spotrna.py (98%)
#  create mode 100755 setup.py
#  create mode 100644 tests/__init__.py
#  create mode 100644 tests/test_encoding_utils.py
# running install
# /usr/local/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# /usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py:147: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   EasyInstallDeprecationWarning,
# running bdist_egg
# running egg_info
# creating rnadeep.egg-info
# writing rnadeep.egg-info/PKG-INFO
# writing dependency_links to rnadeep.egg-info/dependency_links.txt
# writing requirements to rnadeep.egg-info/requires.txt
# writing top-level names to rnadeep.egg-info/top_level.txt
# writing manifest file 'rnadeep.egg-info/SOURCES.txt'
# reading manifest file 'rnadeep.egg-info/SOURCES.txt'
# writing manifest file 'rnadeep.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/rnadeep
# copying rnadeep/encoding_utils.py -> build/lib/rnadeep
# copying rnadeep/sliding_window.py -> build/lib/rnadeep
# copying rnadeep/lstm_models.py -> build/lib/rnadeep
# copying rnadeep/metrics.py -> build/lib/rnadeep
# copying rnadeep/spotrna.py -> build/lib/rnadeep
# copying rnadeep/__init__.py -> build/lib/rnadeep
# copying rnadeep/sampling.py -> build/lib/rnadeep
# copying rnadeep/data_generators.py -> build/lib/rnadeep
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/encoding_utils.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/sliding_window.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/lstm_models.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/metrics.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/spotrna.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/__init__.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/sampling.py -> build/bdist.linux-x86_64/egg/rnadeep
# copying build/lib/rnadeep/data_generators.py -> build/bdist.linux-x86_64/egg/rnadeep
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/encoding_utils.py to encoding_utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/sliding_window.py to sliding_window.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/lstm_models.py to lstm_models.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/metrics.py to metrics.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/spotrna.py to spotrna.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/sampling.py to sampling.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/rnadeep/data_generators.py to data_generators.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying rnadeep.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying rnadeep.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying rnadeep.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying rnadeep.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying rnadeep.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/rnadeep-0.1-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing rnadeep-0.1-py3.7.egg
# Copying rnadeep-0.1-py3.7.egg to /usr/local/lib/python3.7/site-packages
# Adding rnadeep 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/site-packages/rnadeep-0.1-py3.7.egg
# Processing dependencies for rnadeep==0.1
# Searching for tensorflow
# Reading https://pypi.org/simple/tensorflow/
# Downloading https://files.pythonhosted.org/packages/ea/5e/a61e1ebbd38e224e68c7563631ae5a8cfa4bae7df9c73d4766bfd7a23ce5/tensorflow-2.9.0rc1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=a12faf17945c9aae94dba251b7694f4d79f0f775c5388f811cfeecb566cf8eb7
# Best match: tensorflow 2.9.0rc1
# Processing tensorflow-2.9.0rc1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing tensorflow-2.9.0rc1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.7/site-packages
# Adding tensorflow 2.9.0rc1 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing import_pb_to_tensorboard script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/site-packages/tensorflow-2.9.0rc1-py3.7-linux-x86_64.egg
# Searching for numpy
# Reading https://pypi.org/simple/numpy/
# /usr/local/lib/python3.7/site-packages/pkg_resources/__init__.py:125: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   PkgResourcesDeprecationWarning,
# Downloading https://files.pythonhosted.org/packages/64/4a/b008d1f8a7b9f5206ecf70a53f84e654707e7616a771d84c05151a4713e9/numpy-1.22.3.zip#sha256=dbc7601a3b7472d559dc7b933b18b4b66f9aa7452c120e87dfb33d02008c8a18
# Best match: numpy 1.22.3
# Processing numpy-1.22.3.zip
# Writing /tmp/easy_install-olxsu7_e/numpy-1.22.3/setup.cfg
# Running numpy-1.22.3/setup.py -q bdist_egg --dist-dir /tmp/easy_install-olxsu7_e/numpy-1.22.3/egg-dist-tmp-wqmgehib
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 156, in save_modules
#     yield saved
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 198, in setup_context
#     yield
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 259, in run_setup
#     _execfile(setup_script, ns)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 46, in _execfile
#     exec(code, globals, locals)
#   File "/tmp/easy_install-olxsu7_e/numpy-1.22.3/setup.py", line 34, in <module>
# RuntimeError: Python version >= 3.8 required.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "./setup.py", line 23, in <module>
#     packages = ['rnadeep']
#   File "/usr/local/lib/python3.7/site-packages/setuptools/__init__.py", line 87, in setup
#     return distutils.core.setup(**attrs)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/_distutils/core.py", line 148, in setup
#     return run_commands(dist)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/_distutils/core.py", line 163, in run_commands
#     dist.run_commands()
#   File "/usr/local/lib/python3.7/site-packages/setuptools/_distutils/dist.py", line 967, in run_commands
#     self.run_command(cmd)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/dist.py", line 1214, in run_command
#     super().run_command(command)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/_distutils/dist.py", line 986, in run_command
#     cmd_obj.run()
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/install.py", line 74, in run
#     self.do_egg_install()
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/install.py", line 131, in do_egg_install
#     cmd.run(show_deprecation=False)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 426, in run
#     self.easy_install(spec, not self.no_deps)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 668, in easy_install
#     return self.install_item(None, spec, tmpdir, deps, True)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 715, in install_item
#     self.process_distribution(spec, dist, deps)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 761, in process_distribution
#     [requirement], self.local_index, self.easy_install
#   File "/usr/local/lib/python3.7/site-packages/pkg_resources/__init__.py", line 779, in resolve
#     replace_conflicting=replace_conflicting
#   File "/usr/local/lib/python3.7/site-packages/pkg_resources/__init__.py", line 1062, in best_match
#     return self.obtain(req, installer)
#   File "/usr/local/lib/python3.7/site-packages/pkg_resources/__init__.py", line 1074, in obtain
#     return installer(requirement)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 687, in easy_install
#     return self.install_item(spec, dist.location, tmpdir, deps)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 713, in install_item
#     dists = self.install_eggs(spec, download, tmpdir)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 906, in install_eggs
#     return self.build_and_install(setup_script, setup_base)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 1180, in build_and_install
#     self.run_setup(setup_script, setup_base, args)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/command/easy_install.py", line 1164, in run_setup
#     run_setup(setup_script, args)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 262, in run_setup
#     raise
#   File "/usr/local/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 198, in setup_context
#     yield
#   File "/usr/local/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 169, in save_modules
#     saved_exc.resume()
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 143, in resume
#     raise exc.with_traceback(self._tb)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 156, in save_modules
#     yield saved
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 198, in setup_context
#     yield
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 259, in run_setup
#     _execfile(setup_script, ns)
#   File "/usr/local/lib/python3.7/site-packages/setuptools/sandbox.py", line 46, in _execfile
#     exec(code, globals, locals)
#   File "/tmp/easy_install-olxsu7_e/numpy-1.22.3/setup.py", line 34, in <module>
# RuntimeError: Python version >= 3.8 required.
# /content

# %%
# Test of RNA / RNAdeep import
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages") 
print(f"Python version {sys.version}")

#import RNA
#print(f"RNA version {RNA.__version__}")

# Somewhat annoying that we need the "RNAdeep" part here, I acutally don't know why.
import RNAdeep.rnadeep as rnadeep
print(f"rnadeep version {rnadeep.__version__}")
# Out:
# Python version 3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]
# rnadeep version v0.1

# %% [markdown]
# # Let's generate some data (RNAdeep/examples/generate_data.py)

# %%
# Get the data, or use the existing data from the repository?
import os

datadir = "newdata/"
if not os.path.exists(datadir):
  os.mkdir(datadir)

fname = datadir + 'bpRNAinv100.fa'
# !cd newdata/; wget -N http://www.tbi.univie.ac.at/~ivo/bpRNAinv100.fa
print(f'Wrote file: {fname}')
# Out:
# --2022-04-22 17:30:46--  http://www.tbi.univie.ac.at/~ivo/bpRNAinv100.fa
# Resolving www.tbi.univie.ac.at (www.tbi.univie.ac.at)... 131.130.44.61
# Connecting to www.tbi.univie.ac.at (www.tbi.univie.ac.at)|131.130.44.61|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.tbi.univie.ac.at/~ivo/bpRNAinv100.fa [following]
# --2022-04-22 17:30:47--  https://www.tbi.univie.ac.at/~ivo/bpRNAinv100.fa
# Connecting to www.tbi.univie.ac.at (www.tbi.univie.ac.at)|131.130.44.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9557705 (9.1M)
# Saving to: ‘bpRNAinv100.fa’
#
# bpRNAinv100.fa      100%[===================>]   9.11M  7.57MB/s    in 1.2s
#
# 2022-04-22 17:30:48 (7.57 MB/s) - ‘bpRNAinv100.fa’ saved [9557705/9557705]
#
# Wrote file: newdata/bpRNAinv100.fa

# %% [markdown]
# # Let's do some training (RNAdeep/examples/spotrna_padded.py)

# %%
#
# Training with padded data 
#
import os
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

from RNAdeep.rnadeep.spotrna import spotrna
from RNAdeep.rnadeep.metrics import mcc, f1, sensitivity
from RNAdeep.rnadeep.data_generators import PaddedMatrixEncoding
from RNAdeep.rnadeep.sampling import draw_sets

# %%
#
# Get the data for analysis
#
train, valid, tests = list(draw_sets(fname, splits = [0.8,0.1,0.1]))
[train_tags, train_seqs, train_dbrs] = zip(*train)
[valid_tags, valid_seqs, valid_dbrs] = zip(*valid)
[tests_tags, tests_seqs, tests_dbrs] = zip(*tests)

# %%
#
# Model Settings (TODO: update to paper settings!)
#
model = 3
batch_size = 8
epochs = 10
data = os.path.basename(fname)
name = f"spotrna_m{model}_bs{batch_size}_{data}"

# %%
#
# Model Setup
#
train_generator = PaddedMatrixEncoding(batch_size, train_seqs, train_dbrs)
valid_generator = PaddedMatrixEncoding(batch_size, valid_seqs, valid_dbrs)

m = spotrna(model, True)
m.compile(optimizer = "adam",
          loss = "binary_crossentropy", 
          metrics = ["acc", mcc, f1, sensitivity],
          run_eagerly = True)

# Callback functions for fitting.
csv_logger = CSVLogger(f"{name}.csv", separator = ';', append = True)
model_checkpoint = ModelCheckpoint(filepath = name, 
                                   save_weights_only = False, 
                                   monitor = 'val_mcc', 
                                   mode = 'max', 
                                   save_best_only = True)

m.fit(x = train_generator, 
      validation_data = valid_generator,
      epochs = epochs,
      shuffle = True,
      verbose = 1,
      callbacks = [csv_logger, model_checkpoint])

#save model after last epochs 
m.save(f"{name}_ep{epochs}.rnadeep")
# Out:
# Epoch 1/10
# 1139/5782 [====>.........................] - ETA: 6:08:38 - loss: 0.1073 - acc: 0.9928 - mcc: -0.0101 - f1: 0.0047 - sensitivity: 0.0131
